# %% [markdown]
# Que 1.
# The delivery_time.csv dataset contains information about Delivery time and Sorting Time. We have to prepare linear regression and polynimial
# regression model to predict Sorting time on the basis of Delivery Time. Also evaluate the model by using evaluation metrics.

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('delivery_time.csv')
df.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 468.0 bytes

# %%
df.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
df.isna().sum()
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %%
df.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
x = df.drop('Sorting Time',axis=1)
y = df['Sorting Time']

# %%
from sklearn.model_selection import train_test_split

# split the data into train and test data sets
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=0.7,random_state=123456)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[24]])
# Out:
# C:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9.17317371])

# %% [markdown]
# ## Model Evaluation

# %%
y_pred = model.predict(x_test)

y_true = y_test

# %% [markdown]
# ### Mean Absolute Error

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_true,y_pred)
mae
# Out:
# 1.2742186448821415

# %% [markdown]
# ### Mean Squared Error

# %%
from sklearn.metrics import mean_squared_error

# calculate the error
mse = mean_squared_error(y_true, y_pred)
mse
# Out:
# 2.537094840124104

# %% [markdown]
# ### Root Mean Squared Error

# %%
from sklearn.metrics import root_mean_squared_error

rmse = root_mean_squared_error(y_true, y_pred)
rmse
# Out:
# 1.5928260545722197

# %% [markdown]
# ### R2 Score

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_true, y_pred)
r2
# Out:
# 0.1485092659857461

# %% [markdown]
# ## Polynomial Regression

# %%
df['Delivery Time0'] = df['Delivery Time'] ** 0
df['Delivery Time1'] = df['Delivery Time'] ** 1
# df['Delivery Time2'] = df['Delivery Time'] ** 2

# %%
del df['Delivery Time']

# %%
df.head()
# Out:
#    Sorting Time  Delivery Time0  Delivery Time1
# 0            10             1.0           21.00
# 1             4             1.0           13.50
# 2             6             1.0           19.75
# 3             9             1.0           24.00
# 4            10             1.0           29.00

# %%
x = df.drop('Sorting Time', axis=1)
y = df['Sorting Time']

# %%
# split data into train and test sets
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=123456)

# %%
from sklearn.linear_model import LinearRegression

# create the model
model = LinearRegression()

# train the model
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Evaluation

# %%
y_pred = model.predict(x_test)

y_true = y_test

# %%
from sklearn.metrics import mean_absolute_error

# calculate the error
mae = mean_absolute_error(y_true, y_pred)
mae
# Out:
# 1.3155273914948569

# %%
from sklearn.metrics import mean_squared_error

# calculate the error
mse = mean_squared_error(y_true, y_pred)
mse
# Out:
# 2.7860802820350026

# %%
from sklearn.metrics import root_mean_squared_error

rmse = root_mean_squared_error(y_true, y_pred)
rmse
# Out:
# 1.6691555595674725

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_true, y_pred)
r2
# Out:
# 0.06494565876907443
