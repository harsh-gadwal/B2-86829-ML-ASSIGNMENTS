# %% [markdown]
# Que 2.
# The Newspaperdata.csv dataset contains information of nwespapers with their daily sales and sunday sales. We have to predict sunday sales of
# newspaper on the basis of daily sales of newspaper. For that build linear regression and polynomial regression models and evaluate the model by
# using evaluation metrics.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the Data

# %%
df= pd.read_csv('Newspaperdata.csv')
df.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %% [markdown]
# ### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Newspaper  34 non-null     object
#  1   daily      34 non-null     float64
#  2   sunday     34 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 948.0+ bytes

# %%
df.describe()
# Out:
#              daily       sunday
# count    34.000000    34.000000
# mean    430.962471   591.202412
# std     269.211470   376.418051
# min     133.239000   202.614000
# 25%     233.021500   327.769500
# 50%     355.235500   436.712500
# 75%     516.616500   699.735250
# max    1209.225000  1762.015000

# %%
df.isna().sum()
# Out:
# Newspaper    0
# daily        0
# sunday       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

encoder.fit(df['Newspaper'])
df['Newspaper'] = encoder.transform(df['Newspaper'])

# %%
df.corr()
# Out:
#            Newspaper     daily    sunday
# Newspaper   1.000000  0.003978  0.031973
# daily       0.003978  1.000000  0.958154
# sunday      0.031973  0.958154  1.000000

# %%
df.drop('Newspaper',axis=1,inplace=True)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# #### Shuffling and dividing the data into train and test data sets

# %%
x = df.drop('sunday',axis=1)
y= df['sunday']

# %%
from sklearn.model_selection import train_test_split

# split the data into train and test data sets
x_train, x_test, y_train, y_test =  train_test_split(x, y, train_size=0.7,random_state=123456)

# %% [markdown]
# ## Train the Model

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Evaluation

# %%
y_pred = model.predict(x_test)

y_true = y_test

# %%
from sklearn.metrics import mean_absolute_error

# calculate the error
mae = mean_absolute_error(y_true, y_pred)
mae
# Out:
# 69.03104581039037

# %%
from sklearn.metrics import mean_squared_error

# calculate the error
mse = mean_squared_error(y_true, y_pred)
mse
# Out:
# 10522.019905667838

# %%
from sklearn.metrics import root_mean_squared_error

rmse = root_mean_squared_error(y_true, y_pred)
rmse
# Out:
# 102.57689752409085

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_true, y_pred)
r2
# Out:
# 0.921022861751466

# %%
# data visualization
plt.scatter(x['daily'], y, label="data")

# regression line visualization
predictions = model.predict(x)
plt.scatter(x['daily'], predictions, color="red")
plt.plot(x['daily'], predictions, color="red", label="Best fit regression line")

plt.legend()

# %% [markdown]
# ### Polynomial Regression

# %%
# add the polynomial terms of Level
df['daily0'] = df['daily'] ** 0
df['daily1'] = df['daily'] ** 1
# df['daily2'] = df['daily'] ** 2

# %%
del df['daily']

# %%
df.head()
# Out:
#     sunday  daily0   daily1
# 0  488.506     1.0  391.952
# 1  798.298     1.0  516.981
# 2  235.084     1.0  355.628
# 3  299.451     1.0  238.555
# 4  559.093     1.0  537.780

# %%
x = df.drop('sunday', axis=1)
y = df['sunday']

# %%
# split data into train and test sets
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=123456)

# %%
from sklearn.linear_model import LinearRegression

# create the model
model = LinearRegression()

# train the model
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Evaluation

# %%
y_pred = model.predict(x_test)

y_true = y_test

# %%
from sklearn.metrics import mean_absolute_error

# calculate the error
mae = mean_absolute_error(y_true, y_pred)
mae
# Out:
# 73.83795894328938

# %%
from sklearn.metrics import mean_squared_error

# calculate the error
mse = mean_squared_error(y_true, y_pred)
mse
# Out:
# 11495.556198115333

# %%
from sklearn.metrics import root_mean_squared_error

rmse = root_mean_squared_error(y_true, y_pred)
rmse
# Out:
# 107.21733161254916

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_true, y_pred)
r2
# Out:
# 0.913715604110072

# %%
# data visualization
plt.scatter(x['daily1'], y, label="data")

# regression line visualization
predictions = model.predict(x)
plt.scatter(x['daily1'], predictions, color="red")
plt.plot(x['daily1'], predictions, color="red", label="Best fit regression line")

plt.legend()
